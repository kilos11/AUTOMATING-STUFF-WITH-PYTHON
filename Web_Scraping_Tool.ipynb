# %% [markdown]
# <a href="https://colab.research.google.com/github/kilos11/AUTOMATING-STUFF-WITH-PYTHON/blob/main/Web_Scraping_Tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bs4
# !pip install lxml
# !pip install reqeusts
# !pip install html5lib
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement reqeusts (from versions: none)
# ERROR: No matching distribution found for reqeusts
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# #**DOWNLOADING AND SCRAPING CONTENTS OF A WEBPAGE**#

# %%
url = "https://www.farmersweekly.co.za/farming-basics/"
data = requests.get(url).text
soup = BeautifulSoup(data,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html >
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Learn How to Livestock Farm | Farmer's Weekly
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.farmersweekly.co.za/wp/xmlrpc.php" rel="pingback"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#    <link href="https://www.farmersweekly.co.za/app/uploads/2020/02/favfarmers.jpg" rel="icon" type="image/png"/>
#    <link href="https://www.farmersweekly.co.za/app/uploads/2017/04/cropped-siteID-300x300.jpg" rel="apple-touch-icon" sizes="76x76">
# ...

# %%
for link in soup.find_all('a',href= True):
    print(link.get('href'))
# Out:
# https://www.facebook.com/FarmersWeeklySA
# https://flipboard.com/@FarmersWeeklySA
# https://www.instagram.com/farmersweeklysa/
# https://za.linkedin.com/company/farmers-weekly-sa
# https://www.pinterest.com/farmersweeklysa/
# https://www.farmersweekly.co.za/feed/
# https://www.tiktok.com/@farmersweeklysa
# https://twitter.com/FarmersWeeklySA
# https://chat.whatsapp.com/JCT6c3E7U1r6gJyPPbIPsx
# https://www.youtube.com/user/FarmersWeeklySA
# https://www.farmersweekly.co.za/agri-new/
# https://www.farmersweekly.co.za/agri-news/south-africa/
# https://www.farmersweekly.co.za/agri-news/africa/
# https://www.farmersweekly.co.za/agri-news/world/
# https://www.farmersweekly.co.za/opinion/
# https://www.farmersweekly.co.za/agri-news/
# https://www.farmersweekly.co.za/farming-business/
# https://www.farmersweekly.co.za/agri-business/agribusinesses/
# https://www.farmersweekly.co.za/agri-business/empowerment/
# https://www.farmersweekly.co.za/tax-and-management/
# ...

# %% [markdown]
# #**SCRAPE ALL IMAGES TAGS**#

# %%
for link in soup.find_all('img'):
    print(link)
    print(link.get('src'))
# Out:
# <img alt="Farmer\'s weekly logo" class="td-retina-data lazyload" data-retina="https://www.farmersweekly.co.za/app/uploads/2017/04/FW-logo-300x69.png" data-src="https://www.farmersweekly.co.za/app/uploads/2017/04/FW-logo-White-Transparent-BG.png" height="63" src="..." width="272"/>
# ...<img alt="Farmer\'s weekly logo" class="td-retina-data lazyload" data-retina="https://www.farmersweekly.co.za/app/uploads/2017/05/fw-logo-mobile-retina.png" data-src="https://www.farmersweekly.co.za/app/uploads/2017/04/FW-logo-White-Transparent-BG.png" height="63" src="..." width="272"/>
# ...<img alt="Farmer\'s weekly logo" class="td-retina-data lazyload" data-retina="https://www.farmersweekly.co.za/app/uploads/2017/04/FW-logo-300x69.png" data-src="https://www.farmersweekly.co.za/app/uploads/2017/04/FW-logo-White-Transparent-BG.png" height="63" src="..." width="272"/>
# ...

# %% [markdown]
# #**SCRAPE DATA FROM HTML TABLE**#

# %% [markdown]
# #**TAGS**#

# %%
tag_object = soup.title
print(tag_object)
# Out:
# <title>Learn How to Livestock Farm | Farmer's Weekly</title>

# %% [markdown]
# #**CHILDREN,PARENTS & SIBLINGS**#

# %%
tag_child = tag_object.b
tag_string = tag_child.string
print(tag_string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-5d653748d0a2> in <cell line: 2>()
#       1 tag_child = tag_object.b
# ----> 2 tag_string = tag_child.string
#       3 print(tag_string)
#
# AttributeError: 'NoneType' object has no attribute 'string'
